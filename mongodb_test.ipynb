# %%
import pymongo
import pandas as pd
import json

# %%
conn = 'mongodb://localhost:27017'
client = pymongo.MongoClient(conn)

# %%
top_40 = pd.read_csv("K_Resources/top_40.csv")

top_40.set_index('Overall rank', inplace=True)

top_40.head()
# Out:
#              Country or region  Score  Generosity  Perceptions of corruption
# Overall rank
# 1                      Finland  7.769       0.153                      0.393
# 2                      Denmark  7.600       0.252                      0.410
# 3                       Norway  7.554       0.271                      0.341
# 4                      Iceland  7.494       0.354                      0.118
# 5                  Netherlands  7.488       0.322                      0.298

# %%
data = top_40.to_dict(orient = 'records')
data
# Out:
# [{'Country or region': 'Finland',
#   'Score': 7.769,
#   'Generosity': 0.153,
#   'Perceptions of corruption': 0.393},
#  {'Country or region': 'Denmark',
#   'Score': 7.6,
#   'Generosity': 0.252,
#   'Perceptions of corruption': 0.41},
#  {'Country or region': 'Norway',
#   'Score': 7.5539999999999985,
#   'Generosity': 0.271,
#   'Perceptions of corruption': 0.341},
#  {'Country or region': 'Iceland',
#   'Score': 7.494,
#   'Generosity': 0.354,
#   'Perceptions of corruption': 0.118},
#  {'Country or region': 'Netherlands',
#   'Score': 7.487999999999999,
#   'Generosity': 0.322,
#   'Perceptions of corruption': 0.298},
#  {'Country or region': 'Switzerland',
#   'Score': 7.48,
#   'Generosity': 0.263,
#   'Perceptions of corruption': 0.343},
#  {'Country or region': 'Sweden',
#   'Score': 7.343,
#   'Generosity': 0.267,
#   'Perceptions of corruption': 0.373},
#  {'Country or region': 'New Zealand',
#   'Score': 7.307,
#   'Generosity': 0.33,
# ...

# %%
db = client['ResortLocations']
print(db)
# Out:
# Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'ResortLocations')

# %%
db.Top_40.insert_many(data)
